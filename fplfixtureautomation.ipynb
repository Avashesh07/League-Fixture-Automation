# %%
pip install pyomo pandas openpyxl
# Out:
# Collecting pyomo
#   Obtaining dependency information for pyomo from https://files.pythonhosted.org/packages/d1/dc/139e49cee5b003e32bd38d222dfd8ced549078c98809f88f736abd3d7650/Pyomo-6.8.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading Pyomo-6.8.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.0 kB)
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/a8/44/d9502bf0ed197ba9bf1103c9867d5904ddcaf869e52329787fc54ed70cc8/pandas-2.2.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Using cached pandas-2.2.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (89 kB)
# Collecting openpyxl
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting ply (from pyomo)
#   Obtaining dependency information for ply from https://files.pythonhosted.org/packages/a3/58/35da89ee790598a0700ea49b2a66594140f44dec458c07e8e3d4979137fc/ply-3.11-py2.py3-none-any.whl.metadata
#   Downloading ply-3.11-py2.py3-none-any.whl.metadata (844 bytes)
# Collecting numpy>=1.23.2 (from pandas)
#   Obtaining dependency information for numpy>=1.23.2 from https://files.pythonhosted.org/packages/ad/81/c8167192eba5247593cd9d305ac236847c2912ff39e11402e72ae28a4985/numpy-2.1.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata
#   Downloading numpy-2.1.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in ./myenv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Obtaining dependency information for pytz>=2020.1 from https://files.pythonhosted.org/packages/11/c3/005fcca25ce078d2cc29fd559379817424e94885510568bc1bc53d7d5846/pytz-2024.2-py2.py3-none-any.whl.metadata
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Obtaining dependency information for tzdata>=2022.7 from https://files.pythonhosted.org/packages/a6/ab/7e5f53c3b9d14972843a647d8d7a853969a58aecc7559cb3267302c94774/tzdata-2024.2-py2.py3-none-any.whl.metadata
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting et-xmlfile (from openpyxl)
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl.metadata
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six>=1.5 in ./myenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading Pyomo-6.8.0-cp311-cp311-macosx_10_9_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 5.5 MB/s eta 0:00:0000:0100:01m
# Using cached pandas-2.2.3-cp311-cp311-macosx_10_9_x86_64.whl (12.6 MB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 4.8 MB/s eta 0:00:00:00:01
# Downloading numpy-2.1.3-cp311-cp311-macosx_10_9_x86_64.whl (21.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.2/21.2 MB 8.8 MB/s eta 0:00:0000:01:00:01
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 954.0 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: pytz, ply, tzdata, pyomo, numpy, et-xmlfile, pandas, openpyxl
# Successfully installed et-xmlfile-2.0.0 numpy-2.1.3 openpyxl-3.1.5 pandas-2.2.3 ply-3.11 pyomo-6.8.0 pytz-2024.2 tzdata-2024.2
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pyomo.environ import *
from datetime import datetime, timedelta

# %%
# Load data from Excel
teams_df = pd.read_excel('schedule_data.xlsx', sheet_name='Teams')
# Load data from Excel with date parsing
grounds_df = pd.read_excel(
    'schedule_data.xlsx',
    sheet_name='Grounds',
    parse_dates=['Date'],
)
dates_sorted = sorted(grounds_df['Date'].tolist())

teams = teams_df['TeamName'].tolist()

# %%
grounds_df
# Out:
#          Date  Kerava  Tikkurila  Käpylä
# 0  2024-08-03       1          0       0
# 1  2024-08-02       1          0       0
# 2  2024-07-30       1          0       0
# 3  2024-07-29       1          0       0
# 4  2024-07-28       1          0       0
# 5  2024-07-27       1          0       0
# 6  2024-07-25       1          0       0
# 7  2024-07-24       1          0       0
# 8  2024-07-23       1          0       0
# 9  2024-07-22       1          0       0
# 10 2024-07-21       1          0       0
# 11 2024-07-20       1          0       0
# 12 2024-07-19       1          0       0
# 13 2024-07-17       1          0       0
# 14 2024-07-16       1          0       0
# 15 2024-07-13       1          0       0
# 16 2024-07-12       1          0       0
# 17 2024-07-10       1          0       0
# 18 2024-07-08       1          0       0
# 19 2024-07-07       1          0       0
# 20 2024-07-06       1          0       0
# 21 2024-07-05       1          0       0
# 22 2024-07-03       1          0       0
# 23 2024-07-02       1          0       0
# 24 2024-07-01       1          0       0
# 25 2024-06-30       1          0       0
# 26 2024-06-29       1          0       0
# 27 2024-06-26       1          0       0
# 28 2024-06-25       1          0       0
# 29 2024-06-24       1          0       0
# 30 2024-06-19       1          0       0
# 31 2024-06-18       1          0       0
# 32 2024-06-12       1          0       0
# 33 2024-06-11       1          0       0
# 34 2024-06-09       1          0       0
# 35 2024-06-08       1          0       0
# 36 2024-06-07       1          0       0
# 37 2024-06-05       1          0       0
# 38 2024-06-04       1          0       0
# 39 2024-06-02       1          0       0
# 40 2024-06-01       1          0       0

# %%
teams
# Out:
# ['Empire Lions',
#  'Greater Helsinki Markhors',
#  'The J Team Jaguars',
#  'Helsinki Titans',
#  'TreCC Amperes',
#  'Vantaa Legends',
#  'SKK Rapids',
#  'BTCC Thundercats']

# %%
# Extract dates and grounds
dates = pd.to_datetime(grounds_df['Date'], format='%m/%d/%Y').tolist()
grounds = list(grounds_df.columns)
grounds.remove('Date')  # Remove the 'Date' column to get ground names

# %%
grounds
# Out:
# ['Kerava', 'Tikkurila', 'Käpylä']

# %%
# Initialize a dictionary to hold ground capacities
ground_capacity = {}

for idx, row in grounds_df.iterrows():
    date = row['Date']
    is_weekend_flag = row['IsWeekend']
    for ground in grounds:
        if row[ground] == 1:
            if is_weekend_flag:
                capacity = 3  # 3 matches on weekends
            else:
                capacity = 1  # 1 match on weekdays
            ground_capacity[(ground, date)] = capacity
        else:
            ground_capacity[(ground, date)] = 0  # Ground unavailable

# %%
ground_capacity
# Out:
# {('Kerava', Timestamp('2024-08-03 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-08-03 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-08-03 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-08-02 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-08-02 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-08-02 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-30 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-30 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-30 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-29 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-29 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-29 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-28 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-07-28 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-28 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-27 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-07-27 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-27 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-25 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-25 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-25 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-24 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-24 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-24 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-23 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-23 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-23 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-22 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-22 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-22 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-21 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-07-21 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-21 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-20 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-07-20 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-20 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-19 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-19 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-19 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-17 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-17 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-17 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-16 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-16 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-16 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-13 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-07-13 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-13 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-12 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-12 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-12 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-10 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-10 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-10 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-08 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-08 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-08 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-07 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-07-07 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-07 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-06 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-07-06 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-06 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-05 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-05 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-05 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-03 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-03 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-03 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-02 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-02 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-02 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-07-01 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-07-01 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-07-01 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-30 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-06-30 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-30 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-29 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-06-29 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-29 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-26 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-26 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-26 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-25 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-25 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-25 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-24 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-24 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-24 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-19 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-19 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-19 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-18 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-18 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-18 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-12 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-12 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-12 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-11 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-11 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-11 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-09 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-06-09 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-09 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-08 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-06-08 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-08 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-07 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-07 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-07 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-05 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-05 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-05 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-04 00:00:00')): 1,
#  ('Tikkurila', Timestamp('2024-06-04 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-04 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-02 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-06-02 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-02 00:00:00')): 0,
#  ('Kerava', Timestamp('2024-06-01 00:00:00')): 3,
#  ('Tikkurila', Timestamp('2024-06-01 00:00:00')): 0,
#  ('Käpylä', Timestamp('2024-06-01 00:00:00')): 0}

# %%
# Function to determine if a date is a weekend
def is_weekend(date):
    return 1 if date.weekday() >= 5 else 0  # 1 for Saturday/Sunday, 0 otherwise

# Add a column to indicate weekend
grounds_df['IsWeekend'] = grounds_df['Date'].apply(is_weekend)

# %%
from itertools import permutations

# Generate all ordered pairs (home, away) excluding self-matches
matches = [(h, a) for h in teams for a in teams if h != a]

# %%
# Initialize the model
model = ConcreteModel()

# Sets
model.Teams = Set(initialize=teams)
model.Dates = Set(initialize=dates_sorted)
model.Grounds = Set(initialize=grounds)
model.Matches = Set(initialize=matches, dimen=2)

# Ground Availability Parameter
model.GroundAvailability = Param(model.Grounds, model.Dates, initialize=ground_capacity, default=0)

# Determine if a date is weekend
date_weekend = {date: is_weekend(date) for date in dates_sorted}
model.IsWeekend = Param(model.Dates, initialize=date_weekend, within=Binary)

# Map each date to its ISO week number
date_to_week = {date: date.isocalendar()[1] for date in dates_sorted}

# Create a set of unique weeks
weeks = sorted(set(date_to_week.values()))
model.Weeks = Set(initialize=weeks)

# Parameter to map dates to weeks
model.DateToWeek = Param(model.Dates, initialize=date_to_week, within=NonNegativeIntegers)


# Binary variable: y[h, a, d, g] = 1 if match (h, a) is scheduled on date d at ground g
model.y = Var(model.Matches, model.Dates, model.Grounds, domain=Binary)

# %%
special_team = 'TreCC Amperes'
regular_teams = [t for t in teams if t != special_team]

# %%
def match_scheduled_once_rule(model, h, a):
    return sum(model.y[h, a, d, g] for d in model.Dates for g in model.Grounds) == 1
model.MatchScheduledOnce = Constraint(model.Matches, rule=match_scheduled_once_rule)

def ground_capacity_rule(model, g, d):
    return sum(model.y[h, a, d, g] for h, a in model.Matches) <= model.GroundAvailability[g, d]
model.GroundCapacityConstraint = Constraint(model.Grounds, model.Dates, rule=ground_capacity_rule)

def team_two_match_per_day_rule(model, t, d):
    return sum(model.y[h, a, d, g] for h, a in model.Matches if h == t or a == t for g in model.Grounds) <= 2
model.TeamTwoMatchPerDay = Constraint(model.Teams, model.Dates, rule=team_two_match_per_day_rule)

# %%
# 4. No Team Plays More Than Two Matches Per Week
def team_max_two_matches_per_week_rule(model, t, w):
    # Sum of matches for team t in week w
    return sum(model.y[h, a, d, g] 
               for d in model.Dates if model.DateToWeek[d] == w 
               for g in model.Grounds 
               for (h, a) in model.Matches if h == t or a == t) <= 2
model.TeamMaxTwoMatchesPerWeek = Constraint(model.Teams, model.Weeks, rule=team_max_two_matches_per_week_rule)

# %%
# 5. TreCC Amperes: Matches Only on Weekends
def trecc_weekend_only_rule(model, h, a, d, g):
    if h == special_team or a == special_team:
        return model.y[h, a, d, g] <= model.IsWeekend[d]
    else:
        return Constraint.Skip
model.TreccWeekendOnly = Constraint(model.Matches, model.Dates, model.Grounds, rule=trecc_weekend_only_rule)

# 6. TreCC Amperes: No More Than 2 Matches Per Weekend Day
def trecc_max_two_matches_per_day_rule(model, d):
    if model.IsWeekend[d] == 1:
        return sum(model.y[h, a, d, g] 
                   for h, a in model.Matches if h == special_team or a == special_team 
                   for g in model.Grounds) <= 2
    else:
        return Constraint.Skip
model.TreccMaxTwoMatchesPerDay = Constraint(model.Dates, rule=trecc_max_two_matches_per_day_rule)

# %%
model.Objective = Objective(expr=0, sense=minimize)

# %%
# Choose the solver
solver = SolverFactory('glpk',executable='/usr/local/bin/glpsol')  

# Solve the model
result = solver.solve(model, tee=True)
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --write /var/folders/23/m666xnxn3yb59qvbhl4ddhk80000gn/T/tmp1no49076.glpk.raw
#  --wglp /var/folders/23/m666xnxn3yb59qvbhl4ddhk80000gn/T/tmp1oocxvzw.glpk.glp
#  --cpxlp /var/folders/23/m666xnxn3yb59qvbhl4ddhk80000gn/T/tmp711l316x.pyomo.lp
# Reading problem data from '/var/folders/23/m666xnxn3yb59qvbhl4ddhk80000gn/T/tmp711l316x.pyomo.lp'...
# /var/folders/23/m666xnxn3yb59qvbhl4ddhk80000gn/T/tmp711l316x.pyomo.lp:57507: warning: lower bound of variable 'x4' redefined
# /var/folders/23/m666xnxn3yb59qvbhl4ddhk80000gn/T/tmp711l316x.pyomo.lp:57507: warning: upper bound of variable 'x4' redefined
# 2323 rows, 6889 columns, 43638 non-zeros
# 6888 integer variables, all of which are binary
# 64395 lines were read
# Writing problem data to '/var/folders/23/m666xnxn3yb59qvbhl4ddhk80000gn/T/tmp1oocxvzw.glpk.glp'...
# 55177 lines were written
# GLPK Integer Optimizer 5.0
# 2323 rows, 6889 columns, 43638 non-zeros
# 6888 integer variables, all of which are binary
# Preprocessing...
# 490 rows, 1918 columns, 11704 non-zeros
# 1918 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 490
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 490 rows, 1918 columns, 11704 non-zeros
#       0: obj =   0.000000000e+00 inf =   2.570e+02 (18)
#     202: obj =   0.000000000e+00 inf =   9.485e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   202: mip =     not found yet >=              -inf        (1; 0)
# +  1204: >>>>>   0.000000000e+00 >=   0.000000000e+00   0.0% (69; 0)
# +  1204: mip =   0.000000000e+00 >=     tree is empty   0.0% (0; 137)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.8 secs
# Memory used: 8.0 Mb (8388960 bytes)
# Writing MIP solution to '/var/folders/23/m666xnxn3yb59qvbhl4ddhk80000gn/T/tmp1no49076.glpk.raw'...
# 9221 lines were written

# %%
from pyomo.opt import SolverStatus, TerminationCondition

# Check if the solution is feasible
if (result.solver.status == SolverStatus.ok) and (result.solver.termination_condition == TerminationCondition.optimal):
    # Retrieve the schedule
    schedule = []
    for h, a in model.Matches:
        for d in model.Dates:
            for g in model.Grounds:
                if value(model.y[h, a, d, g]) == 1:
                    schedule.append({
                        'HomeTeam': h,
                        'AwayTeam': a,
                        'Date': d.strftime('%d-%m-%Y'),
                        'Ground': g
                    })
    schedule_df = pd.DataFrame(schedule)
    schedule_df['Date'] = pd.to_datetime(schedule_df['Date'], format='%d-%m-%Y')

    # Sort the schedule by date
    schedule_df.sort_values(by='Date', inplace=True)
    
    # Reset index
    schedule_df.reset_index(drop=True, inplace=True)
    
    # Display the schedule
    print(schedule_df)
    
    # Optionally, export to Excel
    #schedule_df.to_excel('schedule_output.xlsx', index=False)
else:
    print('No feasible solution found.')
    print('Solver Status:', result.solver.status)
    print('Termination Condition:', result.solver.termination_condition)
# Out:
#                      HomeTeam                   AwayTeam       Date  Ground
# 0              Vantaa Legends               Empire Lions 2024-06-01  Kerava
# 1                Empire Lions              TreCC Amperes 2024-06-01  Kerava
# 2            BTCC Thundercats            Helsinki Titans 2024-06-01  Kerava
# 3             Helsinki Titans              TreCC Amperes 2024-06-02  Kerava
# 4                  SKK Rapids         The J Team Jaguars 2024-06-02  Kerava
# 5          The J Team Jaguars             Vantaa Legends 2024-06-02  Kerava
# 6                Empire Lions             Vantaa Legends 2024-06-04  Kerava
# 7   Greater Helsinki Markhors         The J Team Jaguars 2024-06-05  Kerava
# 8                  SKK Rapids            Helsinki Titans 2024-06-07  Kerava
# 9   Greater Helsinki Markhors           BTCC Thundercats 2024-06-08  Kerava
# 10               Empire Lions            Helsinki Titans 2024-06-08  Kerava
# 11             Vantaa Legends                 SKK Rapids 2024-06-09  Kerava
# 12              TreCC Amperes         The J Team Jaguars 2024-06-09  Kerava
# 13               Empire Lions         The J Team Jaguars 2024-06-11  Kerava
# 14               Empire Lions                 SKK Rapids 2024-06-12  Kerava
# 15           BTCC Thundercats               Empire Lions 2024-06-18  Kerava
# 16  Greater Helsinki Markhors             Vantaa Legends 2024-06-19  Kerava
# 17            Helsinki Titans                 SKK Rapids 2024-06-26  Kerava
# 18              TreCC Amperes               Empire Lions 2024-06-29  Kerava
# 19            Helsinki Titans           BTCC Thundercats 2024-06-29  Kerava
# 20             Vantaa Legends  Greater Helsinki Markhors 2024-06-29  Kerava
# 21             Vantaa Legends           BTCC Thundercats 2024-06-30  Kerava
# 22         The J Team Jaguars              TreCC Amperes 2024-06-30  Kerava
# 23         The J Team Jaguars                 SKK Rapids 2024-06-30  Kerava
# 24               Empire Lions           BTCC Thundercats 2024-07-01  Kerava
# 25  Greater Helsinki Markhors                 SKK Rapids 2024-07-02  Kerava
# 26         The J Team Jaguars               Empire Lions 2024-07-03  Kerava
# 27  Greater Helsinki Markhors            Helsinki Titans 2024-07-05  Kerava
# 28                 SKK Rapids              TreCC Amperes 2024-07-06  Kerava
# 29              TreCC Amperes            Helsinki Titans 2024-07-06  Kerava
# 30           BTCC Thundercats             Vantaa Legends 2024-07-07  Kerava
# 31         The J Team Jaguars  Greater Helsinki Markhors 2024-07-08  Kerava
# 32            Helsinki Titans  Greater Helsinki Markhors 2024-07-10  Kerava
# 33            Helsinki Titans               Empire Lions 2024-07-12  Kerava
# 34              TreCC Amperes             Vantaa Legends 2024-07-13  Kerava
# 35              TreCC Amperes                 SKK Rapids 2024-07-13  Kerava
# 36         The J Team Jaguars           BTCC Thundercats 2024-07-13  Kerava
# 37               Empire Lions  Greater Helsinki Markhors 2024-07-16  Kerava
# 38         The J Team Jaguars            Helsinki Titans 2024-07-17  Kerava
# 39  Greater Helsinki Markhors               Empire Lions 2024-07-19  Kerava
# 40             Vantaa Legends              TreCC Amperes 2024-07-20  Kerava
# 41              TreCC Amperes           BTCC Thundercats 2024-07-20  Kerava
# 42                 SKK Rapids           BTCC Thundercats 2024-07-20  Kerava
# 43            Helsinki Titans             Vantaa Legends 2024-07-21  Kerava
# 44            Helsinki Titans         The J Team Jaguars 2024-07-22  Kerava
# 45             Vantaa Legends            Helsinki Titans 2024-07-23  Kerava
# 46           BTCC Thundercats                 SKK Rapids 2024-07-24  Kerava
# 47           BTCC Thundercats         The J Team Jaguars 2024-07-25  Kerava
# 48                 SKK Rapids             Vantaa Legends 2024-07-27  Kerava
# 49  Greater Helsinki Markhors              TreCC Amperes 2024-07-27  Kerava
# 50              TreCC Amperes  Greater Helsinki Markhors 2024-07-27  Kerava
# 51             Vantaa Legends         The J Team Jaguars 2024-07-29  Kerava
# 52                 SKK Rapids               Empire Lions 2024-07-30  Kerava
# 53                 SKK Rapids  Greater Helsinki Markhors 2024-08-02  Kerava
# 54           BTCC Thundercats  Greater Helsinki Markhors 2024-08-03  Kerava
# 55           BTCC Thundercats              TreCC Amperes 2024-08-03  Kerava
